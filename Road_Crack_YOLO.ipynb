# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-6ff49385-1d91-4da7-a6cd-7d32feaea935" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6ff49385-1d91-4da7-a6cd-7d32feaea935">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os

print(os.listdir())
# Out:
# ['.config', 'YOLO.zip', 'sample_data']

# %%
# !unzip "YOLO.zip" -d /content/crack_dataset
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/crack_dataset/train/images/86ae68901k011db9c5976d3c9569be3d_JPG.rf.2a2de5946beb416a17a95c79e1079a65.jpg
#   inflating: /content/crack_dataset/train/images/86ae68901k011db9c5976d3c9569be3d_JPG.rf.3392b45ebd64afb88242d5366aefe84f.jpg
#   inflating: /content/crack_dataset/train/images/86ae68901k011db9c5976d3c9569be3d_JPG.rf.5ec89e4c85b49ae4eca718606a23cf3c.jpg
#   inflating: /content/crack_dataset/train/images/86f98d6c7kc03c29ab60f7b92db06ea0_JPG.rf.0df9df5a038e996c48519b2e311b3dff.jpg
#   inflating: /content/crack_dataset/train/images/86f98d6c7kc03c29ab60f7b92db06ea0_JPG.rf.4569399b36f485c52e5a1af9122246de.jpg
#   inflating: /content/crack_dataset/train/images/86f98d6c7kc03c29ab60f7b92db06ea0_JPG.rf.f597954a71da20faa1152b8b3484bd0a.jpg
#   inflating: /content/crack_dataset/train/images/87063ce93g09e42c41ce88c6ae306449_JPG.rf.59abe81dfe709ebeda2ceee1d47ecba1.jpg
# ...

# %%
import os

for root, dirs, files in os.walk('/content/crack_dataset'):
    print(root)
# Out:
# /content/crack_dataset
# /content/crack_dataset/test
# /content/crack_dataset/test/labels
# /content/crack_dataset/test/images
# /content/crack_dataset/valid
# /content/crack_dataset/valid/labels
# /content/crack_dataset/valid/images
# /content/crack_dataset/train
# /content/crack_dataset/train/labels
# /content/crack_dataset/train/images

# %%
# !pip install ultralytics -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 1.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 22.1 MB/s eta 0:00:00

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# !find /content/crack_dataset -name "data.yaml"
# Out:
# /content/crack_dataset/data.yaml

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="/content/crack_dataset/data.yaml",
    epochs=1,
    imgsz=416,
    batch=16
)
# Out:
# Ultralytics 8.4.62 🚀 Python-3.12.13 torch-2.11.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# ...

# %%
import os

print(os.listdir("/content/runs/detect/train/weights"))
# Out:
# ['last.pt', 'best.pt']

# %%
from google.colab import files

files.download("/content/runs/detect/train/weights/best.pt")

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-af7abecf-d7ab-45f6-89fb-d5c3bcd5dbf1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-af7abecf-d7ab-45f6-89fb-d5c3bcd5dbf1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from ultralytics import YOLO

model = YOLO("/content/runs/detect/train/weights/best.pt")

results = model.predict(
    source="/content/crack_dataset/train/images/aaef564f1n68f787301b64845f40370d_JPG.rf.749987f88b0a393f2e8a70438ca1b730.jpg",
    save=True,
    conf=0.25
)
# Out:
# image 1/1 /content/crack_dataset/train/images/aaef564f1n68f787301b64845f40370d_JPG.rf.749987f88b0a393f2e8a70438ca1b730.jpg: 640x640 2 crackss, 274.3ms
# Speed: 9.9ms preprocess, 274.3ms inference, 5.2ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/runs/detect/predict

# %%
from IPython.display import Image

Image("/content/crack_dataset/train/images/aaef564f1n68f787301b64845f40370d_JPG.rf.749987f88b0a393f2e8a70438ca1b730.jpg")

# %%
from google.colab import files

files.download("/content/runs/detect/train/weights/best.pt")

# %%
from ultralytics import YOLO

model = YOLO("/content/runs/detect/train/weights/best.pt")

results = model.predict(
    source="/content/crack_dataset/train/images/aaef564f1n68f787301b64845f40370d_JPG.rf.749987f88b0a393f2e8a70438ca1b730.jpg",
    save=True,
    conf=0.25
)
# Out:
# image 1/1 /content/crack_dataset/train/images/aaef564f1n68f787301b64845f40370d_JPG.rf.749987f88b0a393f2e8a70438ca1b730.jpg: 640x640 2 crackss, 622.8ms
# Speed: 19.9ms preprocess, 622.8ms inference, 12.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/runs/detect/predict-2

# %%
from IPython.display import Image

Image("/content/runs/detect/predict/aaef564f1n68f787301b64845f40370d_JPG.rf.749987f88b0a393f2e8a70438ca1b730.jpg")
